# %%
sc.version
# Out:
# '3.1.3'

# %%
server_name = "jdbc:sqlserver://34.125.122.123"
database_name = "TestDB"
url = server_name + ";" + "databaseName=" + database_name + ";"

table_name = "Inventory"
username = "SA"
password = "Passw0rd123456" # Please specify password here

# %%
url
# Out:
# 'jdbc:sqlserver://34.125.122.123;databaseName=TestDB;'

# %%
jdbcDF = spark.read.format("jdbc")\
        .option("url", url) \
        .option("dbtable", 'spark_user_table1') \
        .option("user", username) \
        .option("password", password)\
        .option("driver", "com.microsoft.sqlserver.jdbc.SQLServerDriver")

# %%
raw_df = jdbcDF.load()

# %%
raw_df.show()
# Out:
# [Stage 0:>                                                          (0 + 1) / 1]
# +------+------+--------+
# |gender|income|    name|
# +------+------+--------+
# |     M|1333.4| Aekanun|
# |     F|3334.3|Ornanong|
# +------+------+--------+

# %%
synthetic_df = spark.createDataFrame([{'name':'Aekanun','gender':'M','income':1333.4}\
                                      ,{'name':'Ornanong','gender':'F','income':3334.3}])

# %%
synthetic_df.show()
# Out:
# [Stage 1:>                                                          (0 + 1) / 1]

# %%
synthetic_df.write.mode('overwrite').format("jdbc")\
        .option("url", url) \
        .option("dbtable", "spark_user_table1") \
        .option("user", username) \
        .option("password", password)\
        .option("driver", "com.microsoft.sqlserver.jdbc.SQLServerDriver").save()

# %%
spark.read.format("jdbc")\
        .option("url", url) \
        .option("dbtable", 'spark_user_table1') \
        .option("user", username) \
        .option("password", password)\
        .option("driver", "com.microsoft.sqlserver.jdbc.SQLServerDriver").load().show()
